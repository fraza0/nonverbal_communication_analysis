# %%
import os
os.chdir('/home/fraza0/Desktop/MEI/TESE/nonverbal_communication_analysis')
print("Working Directory:", os.getcwd())

import cv2
import matplotlib.pyplot as plt
import numpy as np
from itertools import islice
# %matplotlib inline
# Out:
# Working Directory: /home/fraza0/Desktop/MEI/TESE/nonverbal_communication_analysis

# %%
f0 = cv2.imread('DATASET_DEP/SYNC/3CLC9VWR/group_frames/task1_pc1000000000040.png')
f1 = cv2.imread('DATASET_DEP/SYNC/3CLC9VWR/group_frames/task1_pc1000000000045.png')

# %%
plt.axis('off')
plt.imshow(cv2.cvtColor(f0, cv2.COLOR_BGR2RGB))

# %%
plt.axis('off')
plt.imshow(cv2.cvtColor(f1, cv2.COLOR_BGR2RGB))

# %%
gs_activity_frame = cv2.absdiff(f0, f1)
plt.axis('off')
plt.imshow(gs_activity_frame)

# %%
gs_frame_diff = cv2.cvtColor(gs_activity_frame, cv2.COLOR_BGR2GRAY)
plt.axis('off')
plt.imshow(gs_frame_diff, cmap='binary')

# %%
_, threshold_frame_diff = cv2.threshold(gs_frame_diff,127,1,cv2.THRESH_BINARY)
plt.axi
plt.imshow(activity_frame, cmap=plt.cm.Reds)

# %%
plt.axis('off')
plt.imshow(cv2.cvtColor(f0, cv2.COLOR_BGR2RGB))
plt.imshow(activity_frame, cmap=plt.cm.Reds, alpha=0.7)
